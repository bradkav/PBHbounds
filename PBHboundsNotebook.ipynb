# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import argparse
import tools

#Specify the plot style
mpl.style.use("PBHbounds.mplstyle")

# %%
fig = plt.figure(figsize=(8,5))

tools.addConstraint("EROS", color="C0", x = 1e-3, y = 2e-2, labeltext="EROS")
tools.addConstraint("WideBinaries", color="C1", x = 1e2, y = 7e-2, fontsize=10, labeltext="Wide Binaries", c = "C1")
tools.addConstraint("X-ray", color="C2", fill=False, x = 100, y = 2e-3, labeltext="X-ray", linewidth = 3, rotation=45)
tools.addConstraint("Evaporation", color="C3", x = 3e-15, y = 1e-3, labeltext = "Evaporation\n(Envelope)")
tools.addConstraint("FL", color="C6", linestyle='--', x = 1e-15, y = 7e-2, labeltext="FL")

plt.axhspan(1, 1.5, facecolor='grey', alpha=0.7, zorder=10)

Msun_min = 1e-18
Msun_max = 1e4

plt.xlim(Msun_min, Msun_max)
plt.ylim(5e-6, 1.5)

tools.setup_axes(fig, major_tick_spacing=3)

#plt.savefig("test.pdf", bbox_inches='tight')
    
plt.show()
